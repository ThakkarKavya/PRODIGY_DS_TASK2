# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\thakk\\OneDrive\\Desktop\\DATA2.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("Missing values before cleaning:")
print(df.isnull().sum())
# Out:
# Missing values before cleaning:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
if df['Age'].isnull().sum()==0:
    print("No missing values in age column")
# Out:
# No missing values in age column

# %%
df['HasCabin']=df['Cabin'].notna().astype(int)

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0])
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
print("Missing values After cleaning:")
print(df.isnull().sum())
# Out:
# Missing values After cleaning:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# HasCabin       0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
print("Distribution of age")
plt.figure(figsize=(10,6))
sns.histplot(df['Age'],kde=True,bins=30)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# Distribution of age

# %%
print("Distribution of Fare")
plt.figure(figsize=(10,6))
sns.histplot(df['Fare'],kde=True,bins=30)
plt.title('Distribution of Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()
# Out:
# Distribution of Fare

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Pclass',y='Survived',data=df)
plt.title('Survival rate by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Survival Rate')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Sex',y='Survived',data=df)
plt.title('Survival rate by Sex')
plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df[df['Survived']==1]['Age'], shade=True,label='Survived',color='orange')
sns.kdeplot(data=df[df['Survived']==0]['Age'], shade=True,label='Not Survived',color='blue')
plt.title('Survival Rate By Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# C:\Users\thakk\AppData\Local\Temp\ipykernel_2948\3867278344.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[df['Survived']==1]['Age'], shade=True,label='Survived',color='orange')
# C:\Users\thakk\AppData\Local\Temp\ipykernel_2948\3867278344.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[df['Survived']==0]['Age'], shade=True,label='Not Survived',color='blue')

# %%
numeric_cols=df.select_dtypes(include=['number'])

# %%
corr_matrix=numeric_cols.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
